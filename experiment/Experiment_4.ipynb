# %%
from google.colab import drive
# %load_ext tensorboard
drive.mount('/content/drive', force_remount=True)

# %%
tensorboard --logdir='/content/drive/My Drive/human_motion/ex_feature_gan/experiment_4/log'

# %%
# !python3 '/content/drive/My Drive/human_motion/src/main.py' --num_lstm 2 --latent_size 10 --num_epoch 4000 --lstm_hidden_size 100 --batch_size 4 --unbalancing_rate 0.2 --mode 'lstm_retrain' \
--train_continue 'off' \
--lstm_ckpt_dir '/content/drive/My Drive/human_motion/ex_classification/experiment_4/checkpoint' \
--lstm_log_dir '/content/drive/My Drive/human_motion/ex_classification/experiment_4/log' \
--lstm_figure_dir '/content/drive/My Drive/human_motion/ex_classification/experiment_4/figure/confusion_matrix.png' \
--oversampling_ckpt_dir '/content/drive/My Drive/human_motion/ex_oversampling/experiment_4/checkpoint' \
--oversampling_log_dir '/content/drive/My Drive/human_motion/ex_oversampling/experiment_4/log' \
--oversampling_figure_dir '/content/drive/My Drive/human_motion/ex_oversampling/experiment_4/figure/confusion_matrix.png' \
--weight_balancing_ckpt_dir '/content/drive/My Drive/human_motion/ex_weight_balancing/experiment_4/checkpoint' \
--weight_balancing_log_dir '/content/drive/My Drive/human_motion/ex_weight_balancing/experiment_4/log' \
--weight_balancing_figure_dir '/content/drive/My Drive/human_motion/ex_weight_balancing/experiment_4/figure/confusion_matrix.png' \
--feature_gan_ckpt_dir '/content/drive/My Drive/human_motion/ex_feature_gan/experiment_4/checkpoint' \
--feature_gan_log_dir '/content/drive/My Drive/human_motion/ex_feature_gan/experiment_4/log' \
--lstm_retrain_ckpt_dir '/content/drive/My Drive/human_motion/ex_lstm_retrain/experiment_4/checkpoint' \
--lstm_retrain_log_dir '/content/drive/My Drive/human_motion/ex_lstm_retrain/experiment_4/log' \
--lstm_retrain_figure_dir '/content/drive/My Drive/human_motion/ex_lstm_retrain/experiment_4/figure/confusion_matrix.png'
