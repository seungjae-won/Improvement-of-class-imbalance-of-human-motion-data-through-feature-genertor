# %%
from google.colab import drive
# %load_ext tensorboard
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
tensorboard --logdir='/content/drive/My Drive/human_motion/balance_classification/experiment_1/log'

# %%
# !python3 '/content/drive/My Drive/human_motion/main.py' --num_lstm 2 --hidden_size 100 --batch_size 4 --train_continue 'on' \
--ckpt_dir '/content/drive/My Drive/human_motion/balance_classification/experiment_1/checkpoint' \
--log_dir '/content/drive/My Drive/human_motion/balance_classification/experiment_1/log'
# Out:
# 2020-10-17 15:28:12.363376: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Epoch [1/400]	train_Loss: 0.6218, train_Accuracy: 0.8025	test_Loss: 1.4513, test_Accuracy: 0.4750
# Epoch [2/400]	train_Loss: 0.5831, train_Accuracy: 0.7794	test_Loss: 0.6874, test_Accuracy: 0.7333
# Epoch [3/400]	train_Loss: 0.5223, train_Accuracy: 0.8130	test_Loss: 0.7583, test_Accuracy: 0.7167
# Epoch [4/400]	train_Loss: 0.4565, train_Accuracy: 0.8403	test_Loss: 0.6770, test_Accuracy: 0.7750
# Epoch [5/400]	train_Loss: 0.6011, train_Accuracy: 0.8025	test_Loss: 0.7131, test_Accuracy: 0.7333
# Epoch [6/400]	train_Loss: 0.4483, train_Accuracy: 0.8466	test_Loss: 0.6227, test_Accuracy: 0.7750
# Epoch [7/400]	train_Loss: 0.3947, train_Accuracy: 0.8613	test_Loss: 0.5601, test_Accuracy: 0.8417
# Epoch [8/400]	train_Loss: 0.3883, train_Accuracy: 0.8655	test_Loss: 0.5910, test_Accuracy: 0.8167
# ...

# %%
print(net)
