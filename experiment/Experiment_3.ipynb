# %%
from google.colab import drive
# %load_ext tensorboard
drive.mount('/content/drive', force_remount=True)

# %%
tensorboard --logdir='/content/drive/My Drive/human_motion/ex_feature_gan/experiment_3/log'

# %%
# !python3 '/content/drive/My Drive/human_motion/src/main.py' --num_lstm 2 --latent_size 10 --lstm_hidden_size 100 --batch_size 4 --unbalancing_rate 0.333 --mode 'feature_gan' \
--train_continue 'off' \
--lstm_ckpt_dir '/content/drive/My Drive/human_motion/ex_classification/experiment_3/checkpoint' \
--lstm_log_dir '/content/drive/My Drive/human_motion/ex_classification/experiment_3/log' \
--oversampling_ckpt_dir '/content/drive/My Drive/human_motion/ex_oversampling/experiment_3/checkpoint' \
--oversampling_log_dir '/content/drive/My Drive/human_motion/ex_oversampling/experiment_3/log' \
--weight_balancing_ckpt_dir '/content/drive/My Drive/human_motion/ex_weight_balancing/experiment_3/checkpoint' \
--weight_balancing_log_dir '/content/drive/My Drive/human_motion/ex_weight_balancing/experiment_3/log' \
--feature_gan_ckpt_dir '/content/drive/My Drive/human_motion/ex_feature_gan/experiment_3/checkpoint' \
--feature_gan_log_dir '/content/drive/My Drive/human_motion/ex_feature_gan/experiment_3/log' \
--lstm_retrain_ckpt_dir '/content/drive/My Drive/human_motion/ex_lstm_retrain/experiment_3/checkpoint' \
--lstm_retrain_log_dir '/content/drive/My Drive/human_motion/ex_lstm_retrain/experiment_3/log'
